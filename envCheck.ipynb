# %%
# importing os module  
import os 
import pprint 
  
# Get the list of user's 
env_var = os.environ 
  
# Print the list of user's 
print("User's Environment variable:") 
pprint.pprint(dict(env_var), width = 1)
# Out:
# User's Environment variable:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\GTI-Felix\\AppData\\Roaming',
#  'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#  'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_1344_ZBBTCKFPWYKTLKTM',
#  'CLICOLOR': '1',
#  'COMMONPROGRAMFILES': 'C:\\Program '
#                        'Files '
#                        '(x86)\\Common '
#                        'Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program '
#                             'Files '
#                             '(x86)\\Common '
#                             'Files',
#  'COMMONPROGRAMW6432': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMPUTERNAME': 'GTI-FELIX',
#  'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'C:\\Users\\GTI-Felix\\.Anaconda3\\Scripts\\conda.exe',
#  'CONDA_PREFIX': 'C:\\Users\\GTI-Felix\\.Anaconda3',
#  'CONDA_PROMPT_MODIFIER': 'False',
#  'CONDA_PYTHON_EXE': 'C:\\Users\\GTI-Felix\\.Anaconda3\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'ELECTRON_NO_ATTACH_CONSOLE': '1',
#  'ELECTRON_RUN_AS_NODE': '1',
#  'GIT_PAGER': 'cat',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\GTI-Felix',
#  'IGCCSVC_DB': '...',
#  'JPY_INTERRUPT_EVENT': '2524',
#  'LOCALAPPDATA': 'C:\\Users\\GTI-Felix\\AppData\\Local',
#  'LOGONSERVER': '\\\\GTI-FELIX',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'NUMBER_OF_PROCESSORS': '16',
#  'NVM_HOME': 'C:\\Users\\GTI-Felix\\AppData\\Roaming\\nvm',
#  'NVM_SYMLINK': 'C:\\Program '
#                 'Files\\nodejs',
#  'ONEDRIVE': 'C:\\Users\\GTI-Felix\\OneDrive',
#  'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#  'OS': 'Windows_NT',
#  'PAGER': 'cat',
#  'PATH': 'C:\\Users\\GTI-Felix\\AppData\\Roaming\\Python\\Python36\\site-packages\\pywin32_system32;c:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Python36-32;c:\\Users\\GTI-Felix\\AppData\\Roaming\\Python\\Python36\\Scripts;C:\\Users\\GTI-Felix\\.Anaconda3;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\usr\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Scripts;C:\\Users\\GTI-Felix\\.Anaconda3\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\condabin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;%NVM_HOME%;%NVM_SYMLINK%;C:\\Program '
#          'Files\\Git\\cmd;C:\\Program '
#          'Files\\Docker\\Docker\\resources\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Python36-32\\Scripts;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Python36-32;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\GTI-Felix\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Microsoft '
#          'VS '
#          'Code\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\oh-my-posh\\bin;C:\\Users\\GTI-Felix\\AppData\\Roaming\\nvm;C:\\Program '
#          'Files\\nodejs;C:\\Users\\GTI-Felix\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Microsoft\\WinGet\\Packages\\Schniz.fnm_Microsoft.Winget.Source_8wekyb3d8bbwe;.;C:\\Users\\GTI-Felix\\.Anaconda3;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\usr\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\Scripts;C:\\Users\\GTI-Felix\\.Anaconda3\\bin;C:\\Users\\GTI-Felix\\.Anaconda3\\condabin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;%NVM_HOME%;%NVM_SYMLINK%;C:\\Program '
#          'Files\\Git\\cmd;C:\\Program '
#          'Files\\Docker\\Docker\\resources\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Python36-32\\Scripts;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Python36-32;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\GTI-Felix\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\Microsoft '
#          'VS '
#          'Code\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\oh-my-posh\\bin;C:\\Users\\GTI-Felix\\AppData\\Roaming\\nvm;C:\\Program '
#          'Files\\nodejs;C:\\Users\\GTI-Felix\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\GTI-Felix\\AppData\\Local\\Microsoft\\WinGet\\Packages\\Schniz.fnm_Microsoft.Winget.Source_8wekyb3d8bbwe;.',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.CPL',
#  'POSH_AZURE_ENABLED': 'False',
#  'POSH_CURSOR_COLUMN': '1',
#  'POSH_CURSOR_LINE': '38',
#  'POSH_GIT_ENABLED': 'False',
#  'POSH_INSTALLER': 'winget',
#  'POSH_PID': '3880',
#  'POSH_SHELL_VERSION': '5.1.22621.3672',
#  'POSH_THEME': 'C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\oh-my-posh\\themes\\paradox.omp.json',
#  'POSH_THEMES_PATH': 'C:\\Users\\GTI-Felix\\AppData\\Local\\Programs\\oh-my-posh\\themes',
#  'POWERLINE_COMMAND': 'oh-my-posh',
#  'PROCESSOR_ARCHITECTURE': 'x86',
#  'PROCESSOR_ARCHITEW6432': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'Intel64 '
#                          'Family '
#                          '6 '
#                          'Model '
#                          '186 '
#                          'Stepping '
#                          '2, '
#                          'GenuineIntel',
#  'PROCESSOR_LEVEL': '6',
#  'PROCESSOR_REVISION': 'ba02',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program '
#                  'Files '
#                  '(x86)',
#  'PROGRAMFILES(X86)': 'C:\\Program '
#                       'Files '
#                       '(x86)',
#  'PROGRAMW6432': 'C:\\Program '
#                  'Files',
#  'PROMPT': '$P$G',
#  'PSMODULEPATH': 'C:\\Users\\GTI-Felix\\Documents\\WindowsPowerShell\\Modules;C:\\Program '
#                  'Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#  'PUBLIC': 'C:\\Users\\Public',
#  'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#  'PYTHONIOENCODING': 'utf-8',
#  'PYTHONUNBUFFERED': '1',
#  'PYTHON_FROZEN_MODULES': 'on',
#  'SESSIONNAME': 'Console',
#  'SSL_CERT_FILE': 'C:\\Users\\GTI-Felix\\.Anaconda3\\Library\\ssl\\cacert.pem',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\Windows',
#  'TEMP': 'C:\\Users\\GTI-FE~1\\AppData\\Local\\Temp',
#  'TERM': 'xterm-color',
#  'TMP': 'C:\\Users\\GTI-FE~1\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'GTI-FELIX',
#  'USERDOMAIN_ROAMINGPROFILE': 'GTI-FELIX',
#  'USERNAME': 'GTI-Felix',
#  'USERPROFILE': 'C:\\Users\\GTI-Felix',
#  'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#  'VSCODE_CLI': '1',
#  'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\GTI-Felix\\AppData\\Roaming\\Code\\CachedData\\5437499feb04f7a586f677b155b039bc2b3669eb',
#  'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#  'VSCODE_CWD': 'C:\\Windows\\System32',
#  'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#  'VSCODE_IPC_HOOK': '\\\\.\\pipe\\d5abe8c3-1.90.2-main-sock',
#  'VSCODE_L10N_BUNDLE_LOCATION': '',
#  'VSCODE_NLS_CONFIG': '{"locale":"en-us","osLocale":"en-us","availableLanguages":{},"_languagePackSupport":true}',
#  'VSCODE_PID': '1344',
#  'WINDIR': 'C:\\Windows',
#  'WSLENV': 'WT_SESSION:WT_PROFILE_ID:',
#  'WT_PROFILE_ID': '{61c54bbd-c2c6-5271-96e7-009a87ff44bf}',
#  'WT_SESSION': '0b7a34c0-56df-4c5f-a7dc-6af1304d5f15',
#  'ZES_ENABLE_SYSMAN': '1',
#  '_CONDA_EXE': 'C:\\Users\\GTI-Felix\\.Anaconda3\\Scripts\\conda.exe',
#  '_CONDA_ROOT': 'C:\\Users\\GTI-Felix\\.Anaconda3',
#  '__CONDA_OPENSLL_CERT_FILE_SET': '1'}

# %%
import time 
current_time = time.strftime('%Y/%m/%d %H:%M:%S',time.localtime(time.time()))
current_time
# Out:
# '2024/06/20 16:04:07'
